# %%
import instaloader
import pandas as pd
# Out:
# C:\Users\ana\anaconda3\lib\site-packages\win_unicode_console\__init__.py:31: RuntimeWarning: sys.stdin.encoding == 'cp1252', whereas sys.stdout.encoding == 'UTF-8', readline hook consumer may assume they are the same
#   readline_hook.enable(use_pyreadline=use_pyreadline)

# %% [markdown]
# ### Informações do usuário

# %%
bot = instaloader.Instaloader()
profile = instaloader.Profile.from_username(bot.context, 'geeks_for_geeks')

# %%
print("Username: ", profile.username)
print("User ID: ", profile.userid)
print("Number of Posts: ", profile.mediacount)
print("Followers Count: ", profile.followers)
print("Following Count: ", profile.followees)
print("Bio: ", profile.biography)
print("External URL: ", profile.external_url)
# Out:
# Username:  geeks_for_geeks
# User ID:  6898786619
# Number of Posts:  1797
# Followers Count:  263075
# Following Count:  3
# Bio:  We've got problems so good, you'll forget about yours😏
# Register for MERN Full Stack Offline Course👇
# External URL:  https://bit.ly/mern_fullstack_offline

# %% [markdown]
# Postagens recentes do usuário:

# %%
rows = []
posts = profile.get_posts()
for post in posts:
    rows.append(dict(date=post.date, likes=post.likes, comments=post.comments, post_url=post.url))
    if len(rows) == 10:
        break
pd.DataFrame(rows)
# Out:
#                  date  likes  comments  \
# 0 2023-04-27 05:41:56   1902       189
# 1 2023-04-26 10:27:50    372         0
# 2 2023-04-25 10:45:49   1932        32
# 3 2023-04-24 10:28:49   3994        16
# 4 2023-04-23 05:51:04   3673        57
# 5 2023-04-22 05:36:43   3467        15
# 6 2023-04-21 05:49:21   6096        68
# 7 2023-04-20 10:49:35   1173         5
# 8 2023-04-19 10:31:08   5482        15
# 9 2023-04-18 15:39:14    599         3
#
#                                             post_url
# 0  https://instagram.fcgh39-1.fna.fbcdn.net/v/t51...
# 1  https://instagram.fcgh39-1.fna.fbcdn.net/v/t51...
# 2  https://instagram.fcgh39-1.fna.fbcdn.net/v/t51...
# 3  https://instagram.fcgh15-1.fna.fbcdn.net/v/t51...
# 4  https://instagram.fcgh15-1.fna.fbcdn.net/v/t51...
# 5  https://instagram.fcgh15-1.fna.fbcdn.net/v/t51...
# 6  https://instagram.fcgh15-1.fna.fbcdn.net/v/t51...
# 7  https://instagram.fcgh39-1.fna.fbcdn.net/v/t51...
# 8  https://instagram.fcgh15-1.fna.fbcdn.net/v/t51...
# 9  https://instagram.fcgh15-1.fna.fbcdn.net/v/t51...

# %%
post.caption
# Out:
# "Work hard in silence, let your badges make the noise 🎖️\U0001fae1\n\nIntroducing GeeksforGeeks Author Badges🎖️🎖️\nYour contribution as a GfG author will now be recognised on the platform! So get ready to brag your badges all over your resumes and your profiles! \n\nVisit your GFG Auth profile right now and check out your badge.\n\nUse #GfGAuthorBadge while sharing your posts and let's create a community of Ace Authors! 🤘🤘\n.\n.\n.\n.\n.\n.\n#GfGAuthorBadges #gfg #geeksforgeeks #contentwriting #tech #coding #badge #author #techblog #techcareers #techcommunity #technicalwriter #codingislife #codingisfun #geeksquad #blogger"

# %%
post.caption_hashtags
# Out:
# ['gfgauthorbadge',
#  'gfgauthorbadges',
#  'gfg',
#  'geeksforgeeks',
#  'contentwriting',
#  'tech',
#  'coding',
#  'badge',
#  'author',
#  'techblog',
#  'techcareers',
#  'techcommunity',
#  'technicalwriter',
#  'codingislife',
#  'codingisfun',
#  'geeksquad',
#  'blogger']

# %% [markdown]
# ### Monitorando uma hashtag

# %%
from datetime import datetime
from instagramy import InstagramHashTag

# %%
loader = instaloader.Instaloader()
data = loader.get_hashtag_posts("fundoquantitativo")

posts = []
for post in data:
    posts.append(dict(text=post.caption, shortcode=post.shortcode, likes=post.likes, 
                      comments=post.comments, date=post.date, username=post.owner_username))
    if len(posts) == 15:
        break
posts_df = pd.DataFrame(posts)

# %%
posts_df.sort_values('comments', ascending=False)
# Out:
#                                                  text    shortcode  likes  \
# 10  Work 📊📝\n\n#investimentos #tecnologia #fundoqu...  Cftt59PuOUs    238
# 9   Conteúdo rico em conhecimento, aproveitem.\n\n...  CgI5la5AW8I     66
# 0   Não perca! Hoje, a partir das 20h, o gestor de...  Crgi-KIuAXL     23
# 3   Times that"ll never be back! 🔥\n.\n.\n.\n.\n.\...  CpigrHoO_AU     38
# 1   Os 5 pilares que desenvolvemos para nossa meto...  Cq5oCNuMWnt      6
# 2   Aparecemos entre os destaques da Órama mais um...  CqLc3Q5O_Kt     26
# 4   As maravilhas antigas resistem ao teste do tem...  CpgmIUeuJj0     43
# 5   Descubra a beleza da vida, onde cada cada cant...  CpQgBQLutPm     27
# 6   Never forget where you came from 🔥\n.\n.\n.\n....  Couie31ugWM     26
# 7   Atenção, #TRAD3\nO TC Traders Club informou ag...  ChE_q9gu-YG     11
# 8   Estaremos na Expert XP entre 2 e 4 de agosto.\...  Cgu_hECLah7      9
# 11  Hoje mais cedo estivemos no Seminário de Inves...  Cejk1RcsjdO     27
# 12  Confira o nosso report semanal - 23 de maio de...  Cd6kyjwO66W      4
# 13  Confira o nosso report semanal - 16 de maio de...  CdoTGTSOont      1
# 14  Confira o nosso report semanal - 09 de maio de...  CdWdHzQORNu      2
#
#     comments                date              username
# 10        17 2022-07-07 14:25:38          thais.rpaiva
# 9          5 2022-07-18 03:48:30            gloubacker
# 0          2 2023-04-26 17:56:42     principalclaritas
# 3          2 2023-03-08 19:12:19            gloubacker
# 1          0 2023-04-11 15:10:34  matheusrodrigues.cga
# 2          0 2023-03-24 16:47:53     principalclaritas
# 4          0 2023-03-08 01:21:31            gloubacker
# 5          0 2023-03-01 19:20:16            gloubacker
# 6          0 2023-02-16 14:47:37            gloubacker
# 7          0 2022-08-10 11:54:48       portalsmallcaps
# 8          0 2022-08-01 22:50:10         enter.capital
# 11         0 2022-06-08 19:22:34           kadimaasset
# 12         0 2022-05-23 21:13:20             brdrasset
# 13         0 2022-05-16 18:52:24             brdrasset
# 14         0 2022-05-09 20:33:40             brdrasset

# %% [markdown]
# Recuperando uma postagem específica

# %%
post = instaloader.Post.from_shortcode(bot.context, 'CgI5la5AW8I')

# %%
post.caption
# Out:
# 'Conteúdo rico em conhecimento, aproveitem.\n\nAcessem meu canal no YouTube para mais conteúdos avançados de análises fundamentalista de mercado, Macroeconomia, Análise Quant + Curva de Juros.\n.\n.\nConteúdo Educacional\n.\n.\n.\n.\n.\n.\n.\n#DAYTRADE #QUANT #PLANILHAQUANT #DAYTRADER #TRADER #bolsadevalores #forex #iqoption #opçõesbinarias #mercadofinanceiro #tapereading #analisegrafica #suporteeresistencia #operando #analisedefluxo #valeapenasertrader #traderganhadinheiro #traderperdedinheiro #traderaovivo #B3 #absorção #TR #macroeconomia #XQuants #SistemaQuant #fundoquantitativo #matemáticafinanceiraaplicada #analisequant #analistasquantitativos'

# %%
post.owner_username
# Out:
# 'gloubacker'

# %%
post.comments
# Out:
# 5

# %% [markdown]
# ### Análise dos textos

# %%
import re
import string
from nltk import word_tokenize
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.corpus import stopwords

def remove_emojis(data):
    emoj = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
                      "]+", re.UNICODE)
    return re.sub(emoj, '', data)

# %%
exclude = set(string.punctuation)
print(exclude)
# Out:
# {'#', '&', ')', '"', '+', '*', '?', '>', '}', '!', ';', '$', '%', ',', '(', '`', '=', '/', '^', '~', '.', ':', '[', '_', '-', '\\', '|', ']', '{', '@', "'", '<'}

# %%
all_posts = posts_df.text.apply(lambda x: x.lower().replace("\n", " "))
clean_posts = all_posts.apply(lambda post: re.sub("#([a-zA-Z0-9_áéóíàèãñõâêôç]+)", " ", post).strip())
clean_posts = clean_posts.apply(lambda post: re.sub("@([a-zA-Z0-9_áéóíàèãñõâêôç]+)", " ", post.lower()).strip())
clean_posts = clean_posts.apply(lambda post: ''.join(ch for ch in post if ch not in exclude))
clean_posts = clean_posts.apply(lambda post: remove_emojis(post))

# %%
clean_posts
# Out:
# 0     não perca hoje a partir das 20h o gestor de es...
# 1     os 5 pilares que desenvolvemos para nossa meto...
# 2     aparecemos entre os destaques da órama mais um...
# 3        times thatll never be back
# 4     as maravilhas antigas resistem ao teste do tem...
# 5     descubra a beleza da vida onde cada cada canto...
# 6                 never forget where you came from
# 7     atenção   o tc traders club informou agora que...
# 8     estaremos na expert xp entre 2 e 4 de agosto  ...
# 9     conteúdo rico em conhecimento aproveitem  aces...
# 10                                                work
# 11    hoje mais cedo estivemos no seminário de inves...
# 12    confira o nosso report semanal  23 de maio de ...
# 13    confira o nosso report semanal  16 de maio de ...
# 14    confira o nosso report semanal  09 de maio de ...
# Name: text, dtype: object

# %%
clean_posts_words = [' '.join([word for word in word_tokenize(text) if word not in stopwords.words('portuguese')]) for text in clean_posts]

# %%
clean_posts_words[:2]
# Out:
# ['perca hoje partir 20h gestor estratégias quantitativas principal claritas gustavo linari rodrigues cfa estará jimmycast falando sobre diferenciais funcionamento desse tipo fundo poderá conhecer sobre claritas quant assista canal jimmy carvalho youtube vemos lá',
#  '5 pilares desenvolvemos metodologia quantitativa norteiam processos dentro gestora quer conhecer produto diferente importante diversificação portfólio conheça clubes quant']

# %%
all_text_newwords = ' '.join(clean_posts_words)

# %%
wc = WordCloud(background_color="white", width=800, height=400, max_words=100)
wc.generate(all_text_newwords)

plt.figure( figsize=(20,10))
plt.axis("off")
plt.imshow(wc, interpolation="bilinear")
plt.tight_layout(pad=0)
plt.show()

# %%
stop = stopwords.words('portuguese')

# %%
stop.extend(['sobre', 'vai', 'algo', 'onde', 'pode', 'aqui', 'link', 'bio'])

# %%
clean_posts_words = [' '.join([word for word in word_tokenize(text) if word not in stop]) for text in clean_posts]
all_text_newwords = ' '.join(clean_posts_words)

# %%
wc = WordCloud(background_color="white", width=800, height=400, max_words=100)
wc.generate(all_text_newwords)

plt.figure( figsize=(20,10))
plt.axis("off")
plt.imshow(wc, interpolation="bilinear")
plt.tight_layout(pad=0)
plt.show()

# %%
import seaborn as sns
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
most_common = Counter(word_tokenize(remove_emojis(all_text_newwords))).most_common(15)

# %%
most_common
# Out:
# [('conhecer', 5),
#  ('claritas', 4),
#  ('quant', 4),
#  ('mercado', 4),
#  ('quantitativos', 3),
#  ('é', 3),
#  ('investimentos', 3),
#  ('confira', 3),
#  ('report', 3),
#  ('semanal', 3),
#  ('maio', 3),
#  ('2022', 3),
#  ('principais', 3),
#  ('acontecimentos', 3),
#  ('movimentam', 3)]

# %%
words, frequency = [], []
for word, count in most_common:
    words.append(word)
    frequency.append(count)
sns.barplot(x = frequency, y = words);

# %%
vec = CountVectorizer(stop_words= stop, ngram_range = (2, 2), min_df=2)
bow = vec.fit_transform(clean_posts_words)

count_values = bow.toarray().sum(axis=0)

ngram_freq = pd.DataFrame(sorted([(count_values[i], k) for k, i in vec.vocabulary_.items()], reverse = True))
ngram_freq.columns = ["frequency", "ngram"]

ngram_most_common = ngram_freq.head(15)

# %%
ngram_most_common
# Out:
#    frequency                      ngram
# 0          3             report semanal
# 1          3  principais acontecimentos
# 2          3         movimentam mercado
# 3          3                  maio 2022
# 4          3             confira report
# 5          3  acontecimentos movimentam
# 6          3            2022 principais
# 7          2         principal claritas
# 8          2             claritas quant

# %%
sns.barplot(x = ngram_most_common['frequency'], y = ngram_most_common['ngram']);

# %%
vec = TfidfVectorizer(stop_words= stop, ngram_range = (2, 2))
tf = vec.fit_transform(clean_posts_words)

count_values = tf.toarray().sum(axis=0)
ngram_freq = pd.DataFrame(sorted([(count_values[i], k) for k, i in vec.vocabulary_.items()], reverse = True))
ngram_freq.columns = ["frequency", "ngram"]

ngram_most_common = ngram_freq.head(10)

# %%
sns.barplot(x = ngram_most_common['frequency'], y = ngram_most_common['ngram'])
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='ngram'>
